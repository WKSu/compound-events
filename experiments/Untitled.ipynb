# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("test.csv", skiprows=6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 78 columns):
# [run number]                        440 non-null int64
# max_altitude_food_available         440 non-null int64
# mean_ash_intensity                  440 non-null int64
# ash_eruption_distance_2             440 non-null int64
# increase_temp_variation             440 non-null int64
# ash_eruption_radius                 440 non-null int64
# growback_rate                       440 non-null int64
# random_ash_fall                     440 non-null float64
# decrease_connection                 440 non-null int64
# max_deviation_prec                  440 non-null int64
# cultural_capital_distribution       440 non-null object
# show-graticules?                    440 non-null bool
# ash_fallout                         440 non-null object
# max_temp_change                     440 non-null int64
# show_volcano_impact                 440 non-null bool
# ...

# %%
df.sort_values(by = "[run number]")
# Out:
#      [run number]  max_altitude_food_available  mean_ash_intensity  \
# 0               1                         2500                  50
# 23              1                         2500                  50
# 49              1                         2500                  50
# 65              1                         2500                  50
# 153             1                         2500                  50
# ..            ...                          ...                 ...
# 377            40                         2500                  50
# 383            40                         2500                  50
# 398            40                         2500                  50
# 430            40                         2500                  50
# 369            40                         2500                  50
#
#      ash_eruption_distance_2  increase_temp_variation  ash_eruption_radius  \
# 0                         50                        0                   40
# ...

# %%
df.columns
# Out:
# Index(['0', '520', '0.1', '180'], dtype='object')
